# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np 
import pandas as pd
import os 

train = pd.read_csv('../train.csv')
test = pd.read_csv('../test.csv')
weather_tr = pd.read_csv('../weather_train.csv')
weather_ts = pd.read_csv('../weather_test.csv')
build = pd.read_csv('../building_metadata.csv')

# %%
weather_tr.shape
# Out:
# (139773, 9)

# %%
weather_tr.isna().sum()
# Out:
# site_id                   0
# timestamp                 0
# air_temperature          55
# cloud_coverage        69173
# dew_temperature         113
# precip_depth_1_hr     50289
# sea_level_pressure    10618
# wind_direction         6268
# wind_speed              304
# dtype: int64

# %%
weather_tr['time']=pd.to_datetime(weather_tr['timestamp'])

# %%
weather_tr # fixed it 
weather_tr['dew_temperature'].fillna(method='ffill',inplace=True)

# %%
weather_tr['sea_level_pressure'][weather_tr[['sea_level_pressure','site_id','timestamp']][weather_tr['sea_level_pressure'].isna()].index+1].plot()

# %%
weather_tr[['site_id']][weather_tr['sea_level_pressure'].isna()].groupby('site_id')['site_id'].count()
# Out:
# site_id
# 0       85
# 1       52
# 2       44
# 3      158
# 4       73
# 5     8755
# 6      175
# 7        8
# 8       85
# 9      239
# 10     141
# 11       8
# 12      56
# 13     120
# 14     110
# 15     509
# Name: site_id, dtype: int64

# %%
weather_tr['cloud_coverage'].plot()
